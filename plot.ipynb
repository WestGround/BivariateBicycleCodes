# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
# Before STIM
dataset = [([2e-4, 5e-4, 1e-3, 2e-3, 3e-3], {8000000: 18, 1038857: 42, 601046: 243, 58948: 334, 11424: 302}, 6), 
           ([1e-3, 2e-3, 3e-3, 5e-3], {4_000_000: 14, 107077: 27, 227013: 963, 13413: 2337}, 12), 
           ([3.5e-3, 4e-3, 5e-3], {14448: 11, 2453: 12, 420: 32}, 18)]
labels = ['[[72, 12, 6]]', '[[144, 12, 12]]', '[[288, 12, 18]]']
color = ['blue', 'black', 'deeppink']
xss = []
yss = []
yerrs = []
for i in range(len(dataset)):
    xs, data, n_c = dataset[i]
    assert isinstance(xs, list) and isinstance(data, dict)
    xss.append(xs)
    yss.append([float(failure)/(float(shots)*n_c) for shots, failure in data.items()])
    yerrs.append([
        1.96 * np.sqrt(max(float(failure)/float(shots), 1 / float(shots)) * (1 - float(failure)/float(shots)) / float(shots)) / n_c
        for shots, failure in data.items()
    ])

fig, ax = plt.subplots(1, 1)
for i in range(len(yss)):
    print(xss[i])
    print(yss[i])
    print(yerrs[i])
    ax.errorbar(xss[i], yss[i], yerr=yerrs[i], marker='.', capsize=3, label=labels[i], color=color[i])
ax.set_ylim(1e-13, 1e-1)
ax.set_xlim(8e-5,1e-2)
ax.loglog()
ax.set_title("Noise performance of small BB codes with BP-OSD Decoder")
ax.set_xlabel("Physical Error Rate")
ax.set_ylabel("Logical Error Rate")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()
fig.set_dpi(120)
# Out:
# [0.0002, 0.0005, 0.001, 0.002, 0.003]
# [3.75e-07, 6.738174743973424e-06, 6.738252978973323e-05, 0.0009443351202189501, 0.004405929038281979]
# [np.float64(1.7324096649428795e-07), np.float64(2.037815759099974e-06), np.float64(8.470566126877823e-06), np.float64(0.00010098924423096337), np.float64(0.0004903119139511153)]
# [0.001, 0.002, 0.003, 0.005]
# [2.9166666666666664e-07, 2.101291593899717e-05, 0.000353503984353319, 0.014519496011332289]
# [np.float64(1.5278407592043455e-07), np.float64(7.925118245513107e-06), np.float64(2.227994593320588e-05), np.float64(0.0005349420875573272)]
# [0.0035, 0.004, 0.005]
# [4.229728066937369e-05, 0.00027177605652941976, 0.004232804232804233]
# [np.float64(2.4986578320901334e-05), np.float64(0.000153395195292738), np.float64(0.0014096149029676494)]

# %%
# After STIM
dataset = [([3e-3], {3000: 11}, 12)]
labels = ['[[144, 12, 12]]']
color = ['black']
xss = []
yss = []
yerrs = []
for i in range(len(dataset)):
    xs, data, n_c = dataset[i]
    assert isinstance(xs, list) and isinstance(data, dict)
    xss.append(xs)
    yss.append([float(failure)/(float(shots)*n_c) for shots, failure in data.items()])
    yerrs.append([
        1.96 * np.sqrt(max(float(failure)/float(shots), 1 / float(shots)) * (1 - float(failure)/float(shots)) / float(shots)) / n_c
        for shots, failure in data.items()
    ])

fig, ax = plt.subplots(1, 1)
for i in range(len(yss)):
    print(xss[i])
    print(yss[i])
    print(yerrs[i])
    ax.errorbar(xss[i], yss[i], yerr=yerrs[i], marker='.', capsize=3, label=labels[i], color=color[i])
ax.set_ylim(1e-13, 1e-1)
ax.set_xlim(8e-5,1e-2)
ax.loglog()
ax.set_title("Noise performance of small BB codes with BP-OSD Decoder")
ax.set_xlabel("Physical Error Rate")
ax.set_ylabel("Logical Error Rate")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()
fig.set_dpi(120)
# Out:
# [0.003]
# [0.0003535158760766165]
# [np.float64(0.0002084709337848422)]
